# %% [markdown]
# # CEC13
# ## D = 10

# %%
library(tidyverse)
library(magrittr)
library(cecb)
options(repr.plot.width=20, repr.plot.height=10)

# %%
get_funcs_data = function(dim, problems) {
    problems %>%
        purrr::map_dfr(function(problem) {
            cecb::get_dfr(
                c("../data/msc-benchmarks/cec13/cma-es-csa",
                  "../data/msc-benchmarks/cec13/cma-es-expth-dp-2-pt-0.1-cec13"),
                config = list(dim = dim, probnums = problem, resp = 51)
            ) %>%
            dplyr::mutate(Func_number = problem)
        })
        
}

# %% [markdown]
# | Index | Name |
# | --- | :---: |
# |   1|Bent Cigar|
# |   2|Sum diff pow|
# |   3|Zakharov|
# |   4|Rosenbrock|
# |   5|Rastrigin|
# |   6|Schaffer|
# |   7|Bi_Rastrigin|
# |   8|Step_Rastrigin|
# |   9|Levy|
# |   10|Schwefel|
# |   11|H1|
# |   12|H2|
# |   13|H3|
# |   14|H4|
# |   15|H5|
# |   16|H6|
# |   17|H7|
# |   18|H8|
# |   19|H9|
# |   20|H10|
# |   21|C1|
# |   22|C2|
# |   23|C3|
# |   24|C4|
# |   25|C5|
# |   26|C6|
# |   27|C7|
# |   28|C8|
# |   29|C9|
# |   30|C10|

# %%
DIM = 10

# %%
unimodals =
    get_funcs_data(DIM, 1:5)
simple_unimodals = 
    get_funcs_data(DIM, 6:20)
comps = 
    get_funcs_data(DIM, 21:28)
# Out:
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#
# ...

# %% [markdown]
# # UNIMODAL FUNCTIONS

# %%
unimodals %>% 
    cecb::ecdf_plot() + 
    ggplot2::facet_grid(cols = dplyr::vars(Func_number))

cecb::get_dfr(
    c("../data/msc-benchmarks/cec13/cma-es-csa",
      "../data/msc-benchmarks/cec13/cma-es-expth-dp-2-pt-0.1-cec13"),
    config = list(dim = DIM, probnums = 1:5, resp = 51)
) %>%
    cecb::ecdf_plot()
# Out:
#  Progress: ──────────────────────────────────────────────────────────────── 100%
# plot without title
# plot without title

# %% [markdown]
# # SIMPLE UNIMODAL FUNCTIONS

# %%
simple_unimodals %>% 
    cecb::ecdf_plot() + 
    ggplot2::facet_grid(cols = dplyr::vars(Func_number))
cecb::get_dfr(
    c("../data/msc-benchmarks/cec13/cma-es-csa",
      "../data/msc-benchmarks/cec13/cma-es-expth-dp-2-pt-0.1-cec13"),
    config = list(dim = DIM, probnums = 6:20, resp = 51)
) %>%
    cecb::ecdf_plot()
# Out:
#  Progress: ──────────────────────────────────────────────────────────────── 100%
# plot without title
# plot without title

# %% [markdown]
# # COMPOSITION FUNCTIONS

# %%
comps %>% 
    cecb::ecdf_plot() + 
    ggplot2::facet_grid(cols = dplyr::vars(Func_number))
cecb::get_dfr(
    c("../data/msc-benchmarks/cec13/cma-es-csa",
      "../data/msc-benchmarks/cec13/cma-es-expth-dp-2-pt-0.1-cec13"),
    config = list(dim = DIM, probnums = 21:28, resp = 51)
) %>%
    cecb::ecdf_plot()
# Out:
#  Progress: ──────────────────────────────────────────────────────────────── 100%
# plot without title
# plot without title
