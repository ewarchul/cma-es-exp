# %% [markdown]
# # Porównanie metod adaptacji $\sigma$ - z CMA

# %%
library(tidyverse)
library(magrittr)
library(furrr)
library(cec2013)
source("../src/cma-es/cma-es.R") # CSA-rule (Ostermeier)
source("../src/cma-es/cma-es-no-sigma.R") # Raw ES
source("../src/cma-es/cma-es-sigma-quant.R") # Quant-rule (Arabas & Warchulski)
source("../src/cma-es/cma-es-sigma-JA-1-2th.R") # Quant-rule (Arabas & Warchulski)
source("../src/cma-es/cma-es-sigma-JA-1-4th.R") # Quant-rule (Arabas & Warchulski)
source("../src/cma-es/cma-es-sigma-JA.R") # Quant-rule (Arabas & Warchulski)
source("../src/cma-es/cma-es-onefifth-sigma.R") # 1/5th rule
source("../src/cma-es/cma-es-onefifth-exp-sigma.R") # 1/5h rule exp (Hansen)
source("../src/cma-es/cma-es-msr-sigma.R") # MSR i.e median success rule (Hansen & Auger)
source("../src/cma-es/cma-es-psr-sigma.R") # PSR i.e population success rule (Loshchilov)
source("../src/eval-funcs.R")
source("../src/exp-utils.R")
source("../src/data-utils.R")
source("../src/plot-funcs.R")
source("../src/quantile-utils.R")
options(repr.plot.width=10, repr.plot.height=10)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.0     ✔ purrr   0.3.3
# ✔ tibble  2.1.3     ✔ dplyr   0.8.5
# ✔ tidyr   1.0.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘magrittr’
#
#
# The following object is masked from ‘package:purrr’:
#
#     set_names
#
#
# The following object is masked from ‘package:tidyr’:
#
#     extract
#
#
# Loading required package: future

# %% [markdown]
# ## Eksperyment
#
#
# * `cma_es()`: CMA-ES z adaptacją $\sigma$ wg CSA
# * `cma_es_no_sigma_quant()`: CMA-ES z "kwantylową" adaptacją $\sigma$
# * `cma_es_no_sigma_msr()`: CMA-ES z medianową regułą adaptacji $\sigma$
# * `cma_es_no_sigma_expth()`: CMA-ES z 1/5th+exp regułą adaptacji $\sigma$
#
#
# 1. $\lambda$ =  $4N$
# 2. maxit = $100*N^2$
# 3. $x \in [-100, 100]^{10}$

# %%
methods = list(
    cma_es,
    cma_es_sigma_JA,
    cma_es_sigma_msr,
    cma_es_sigma_expth,
    cma_es_sigma_quant)

lower = -100
upper = 100 
x0 = 100
CMA_flag = TRUE
alog10 = . %>% abs() %>% log10()

# %% [markdown]
# # D-10

# %%
cec3_eval10 = 
  do_experiment(
                methods,
                cecf_3,
                10,
                x0,
                lower = lower,
                upper = upper,
                CMA = CMA_flag)
# Out:
# Loading required package: sp

# %%
cec15_eval10 = 
    do_experiment(
                methods,
                cecf_15,
                10,
                x0,
                lower = lower,
                upper = upper,
                CMA = CMA_flag)

# %%
cec17_eval10 = 
  do_experiment(
                methods,
                cecf_17,
                10,
                x0,
                lower = lower,
                upper = upper,
                CMA = CMA_flag)

# %%
cec25_eval10 = 
  do_experiment(
                methods,
                cecf_25,
                10,
                x0,
                lower = lower,
                upper = upper,
                CMA = CMA_flag)

# %% [markdown]
# ### Rotated Bent Cigar Function

# %%
cec3_eval10 %>% value_plot(.f=alog10) + xlim(0, 500)
# Out:
# Scale for 'x' is already present. Adding another scale for 'x', which will
# replace the existing scale.
#
# Warning message:
# “Removed 10237 rows containing missing values (geom_point).”
# Warning message:
# “Removed 10237 row(s) containing missing values (geom_path).”
# plot without title

# %% [markdown]
# ### Rotated Schwefel's Function

# %%
cec15_eval10 %>% value_plot(.f=alog10)
# Out:
# plot without title

# %% [markdown]
# ### Lunacek Bi_Rastrigin Function

# %%
cec17_eval10 %>% value_plot(.f=alog10)
# Out:
# plot without title

# %% [markdown]
# ### Composition Function 5 (n=3,Rotated)

# %%
cec25_eval10 %>% value_plot(.f=alog10)
# Out:
# plot without title

# %% [markdown]
# # D-30

# %%
cec3_eval30 = 
  do_experiment(
                methods,
                cecf_3,
                30,
                x0,
                lower = lower,
                upper = upper,
                CMA = CMA_flag)

# %%
cec15_eval30 = 
    do_experiment(
                methods,
                cecf_15,
                30,
                x0,
                lower = lower,
                upper = upper,
                CMA = CMA_flag)

# %%
cec17_eval30 = 
  do_experiment(
                methods,
                cecf_17,
                30,
                x0,
                lower = lower,
                upper = upper,
                CMA = CMA_flag)

# %%
cec25_eval30 = 
  do_experiment(
                methods,
                cecf_25,
                30,
                x0,
                lower = lower,
                upper = upper,
                CMA = CMA_flag)

# %% [markdown]
# ### Rotated Bent Cigar Function

# %%
cec3_eval30 %>% value_plot(.f=alog10)
# Out:
# Error in cec3_eval30 %>% value_plot(.f = alog10): could not find function "%>%"
# Traceback:

# %% [markdown]
# ### Rotated Schwefel's Function

# %%
cec15_eval30 %>% value_plot(.f=alog10)

# %% [markdown]
# ### Lunacek Bi_Rastrigin Function

# %%
cec17_eval30 %>% value_plot(.f=alog10)

# %% [markdown]
# ### Composition Function 5 (n=3,Rotated)

# %%
cec25_eval30 %>% value_plot(.f=alog10)

# %% [markdown]
# # D-50

# %%
cec3_eval50 = 
  do_experiment(
                methods,
                cecf_3,
                50,
                x0,
                lower = lower,
                upper = upper,
                CMA = CMA_flag)

# %%
cec15_eval50 = 
    do_experiment(
                methods,
                cecf_15,
                50,
                x0,
                lower = lower,
                upper = upper,
                CMA = CMA_flag)

# %%
cec17_eval50 = 
  do_experiment(
                methods,
                cecf_17,
                50,
                x0,
                lower = lower,
                upper = upper,
                CMA = CMA_flag)

# %%
cec25_eval50 = 
  do_experiment(
                methods,
                cecf_25,
                50,
                x0,
                lower = lower,
                upper = upper,
                CMA = CMA_flag)

# %% [markdown]
# ### Rotated Bent Cigar Function

# %%
cec3_eval50 %>% value_plot(.f=alog10)

# %% [markdown]
# ### Rotated Schwefel's Function

# %%
cec15_eval50 %>% value_plot(.f=alog10)

# %% [markdown]
# ### Lunacek Bi_Rastrigin Function

# %%
cec17_eval50 %>% value_plot(.f=alog10)

# %% [markdown]
# ### Composition Function 5 (n=3,Rotated)

# %%
cec25_eval50 %>% value_plot(.f=alog10)
# Out:
# plot without title

# %% [markdown]
# # D-100

# %%
cec3_eval100 = 
  do_experiment(
                methods,
                cecf_3,
                100,
                x0,
                lower = lower,
                upper = upper,
                CMA = CMA_flag)

# %%
cec15_eval100 = 
    do_experiment(
                methods,
                cecf_15,
                100,
                x0,
                lower = lower,
                upper = upper,
                CMA = CMA_flag)

# %%
cec17_eval100 = 
  do_experiment(
                methods,
                cecf_17,
                100,
                x0,
                lower = lower,
                upper = upper,
                CMA = CMA_flag)

# %%
cec25_eval100 = 
  do_experiment(
                methods,
                cecf_25,
                100,
                x0,
                lower = lower,
                upper = upper,
                CMA = CMA_flag)

# %% [markdown]
# ### Rotated Bent Cigar Function

# %%
cec3_eval100 %>% value_plot(.f=alog10)

# %% [markdown]
# ### Rotated Schwefel's Function

# %%
cec15_eval100 %>% value_plot(.f=alog10)

# %% [markdown]
# ### Lunacek Bi_Rastrigin Function

# %%
cec17_eval100 %>% value_plot(.f=alog10)

# %% [markdown]
# ### Composition Function 5 (n=3,Rotated)

# %%
cec25_eval100 %>% value_plot(.f=alog10)
# Out:
# plot without title
